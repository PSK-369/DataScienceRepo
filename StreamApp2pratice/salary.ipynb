# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt 
import statistics as sts 
import joblib
import streamlit as st 
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
df1=pd.read_csv(r"C:\Shravan\PythonPratice\supervised\salary_prediction_data.csv",encoding_errors='ignore')

# %%
df2=df1.copy()

# %%
df2.sample(10)
# Out:
#        Education  Experience  Location Job_Title  Age  Gender         Salary
# 164          PhD           8     Rural   Analyst   26    Male  115028.810444
# 602          PhD          14  Suburban  Director   37  Female  144948.937105
# 977     Bachelor           2  Suburban  Director   20  Female   98020.597911
# 386  High School           1     Rural  Director   58  Female   68583.468374
# 652          PhD           4     Rural  Engineer   54    Male  113116.268753
# 873          PhD           9  Suburban  Engineer   25  Female  121976.057371
# 535  High School           7     Urban  Director   21    Male   85397.137796
# 252     Bachelor           1     Urban  Engineer   32    Male   89220.763568
# 734       Master           7  Suburban  Director   45  Female  137105.247320
# 332     Bachelor          27     Rural   Analyst   58  Female   92041.749991

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.drop(columns=['Job_Title'],axis=1,inplace=True)

# %%
df2.rename(columns={"Education":"EDU","Experience":"EXP","Gender":"GEN","Salary":"Sal"},inplace=True)

# %%
df2.rename(columns={"Sal":"SAL"},inplace=True)

# %%
df2.columns
# Out:
# Index(['EDU', 'EXP', 'LOC', 'Age', 'GEN', 'SAL'], dtype='object')

# %%
df2.info()

df2.describe()
df2.isna().sum()
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EDU     1000 non-null   object
#  1   EXP     1000 non-null   int64
#  2   LOC     1000 non-null   object
#  3   Age     1000 non-null   int64
#  4   GEN     1000 non-null   object
#  5   Sal     1000 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB
# EDU    0
# EXP    0
# LOC    0
# Age    0
# GEN    0
# Sal    0
# dtype: int64

# %%
col1=['#ff4d01','#FFFFFF']

plt.figure(figsize=(6,6))
sns.set_theme(style='white',palette=col1)
sns.violinplot(data=df2,x=df2['GEN'],y=df2['SAL'],inner='box',split=False,orient='v')
plt.grid(True)
plt.show()

# %%
col1=['#ff4d01','#FFFFFF']

plt.figure(figsize=(6,6))
sns.set_theme(style='white',palette=col1)
sns.kdeplot(data=df2,x=df2['EXP'],y=df2['SAL'])
plt.grid(True)
plt.show()

# %%
col1=['#ff4d01','#FFFFFF']

plt.figure(figsize=(10,5))
sns.set_theme(style='white',palette=col1)
sns.kdeplot(df2['SAL'],fill=True,)
plt.grid(True)
plt.show()

# %%
df2.columns
# Out:
# Index(['EDU', 'EXP', 'LOC', 'Age', 'GEN', 'SAL'], dtype='object')

# %%
class Anomolies_detction:
    def __init__(self):
        pass 
    def main_function(self):
        pass
    
anmolies_instance=Anomolies_detction()
