# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"F:\BosscoderExcel\haberman.csv",encoding_errors='ignore')

# %%
df.head(10)

# %%
df1=df.copy()

# %%
df1.info()

# %%
df1.columns

# %%
df1.rename(columns={'1.1':'new_col'},inplace=True)

# %%
df1.head(10)

# %%
df1['new_col'].value_counts()

# %%
df1['new_col_numeric']=df1['new_col'].map({1:"yes",2:'no'})

# %%
df1.head(10)

# %%
df1.rename(columns=({'30':'col1','64':'col2'}),inplace=True)

# %%
df1.head(10)

# %%
df1[['col1','col2']].value_counts().head(20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,median_absolute_error,r2_score,rand_score,mean_squared_error,v_measure_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler

import statistics as sts

# %%
df1.isna().sum()

# %%
new_dataframe=pd.DataFrame(df1,columns=['col1','col2','new_col'])

# %%
new_dataframe.head(10)

# %%
plt.figure(figsize=(7,6))
sns.set_theme(style='dark')
sns.kdeplot(new_dataframe.col1,fill=True,color='orange')
sns.displot(new_dataframe['col1'])
plt.show()

# %%
random_data_std=sts.stdev(new_dataframe['col1'])
random_data_std

# %%
random_data_mean=round(sts.mean(new_dataframe['col1']),2)
random_data_mean

# %%
random_data_var=sts.variance(new_dataframe['col1'])
random_data_var

# %%
sns.kdeplot(new_dataframe)
plt.show()
